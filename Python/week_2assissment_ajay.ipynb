# %%
1. NumPy: Create a NumPy array of 20 random integers (1–100). Without using any loops, print all
values above the mean, and multiply the whole array by 2 using vectorization. Explain in a
comment what broadcasting did.
2. Pandas basics: Build a DataFrame of 6 employees with name, department, and salary. Filter
employees earning above 50,000, then use groupby to show the average salary per department.
3. Cleaning & merging: Given two DataFrames — one with student IDs + names, one with student
IDs + marks (containing some NaN values) — merge them, fill missing marks with the column
mean, and drop any duplicate rows.
4. Environments & Git: Create a virtual environment, install pandas into it, and generate a
requirements.txt. Then initialise a Git repository, commit your Week 2 scripts, and paste the output
of git log --oneline. Submit as a text file of commands + output.
5. Data-cleaning exercise: Load the provided messy CSV — fix inconsistent column names, strip
whitespace from strings,

# %% [markdown]
# 1. NumPy: Create a NumPy array of 20 random integers (1–100). Without using any loops, print all
# values above the mean, and multiply the whole array by 2 using vectorization. Explain in a
# comment what broadcasting did.

# %%
import numpy as np
import random
array=np.randint(1,100,size=20)
array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 import numpy as np
#       2 import random
# ----> 3 array=np.randint(1,100,size=20)
#       4 array
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\__init__.py:782, in __getattr__(attr)
#     775 if attr in __expired_attributes__:
#     776     raise AttributeError(
#     777         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     778         f"{__expired_attributes__[attr]}",
#     779         name=None
#     780     )
# --> 782 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'randint'

# %%
# !pip install numpy
import numpy as np
array=np.randint(1,100,size=20)
array
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.5.2)
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\FCI\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 3
#       1 get_ipython().system('pip install numpy')
#       2 import numpy as np
# ----> 3 array=np.randint(1,100,size=20)
#       4 array
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\__init__.py:782, in __getattr__(attr)
#     775 if attr in __expired_attributes__:
#     776     raise AttributeError(
#     777         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     778         f"{__expired_attributes__[attr]}",
#     779         name=None
#     780     )
# --> 782 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'randint'

# %% [markdown]
# 2. Pandas basics: Build a DataFrame of 6 employees with name, department, and salary. Filter
# employees earning above 50,000, then use groupby to show the average salary per department.

# %%
# !pip install pandas
import pandas as pd
df=pd.DataFrame({
    'name':['ram','karn','sham','arjun','akshay','veer'],
    'department':['math','phy','math','math','bio','bio'],
    'salary':[55000,40000,22000,35000,57000,59000]

})
print(df['department'][df['salary']>50000])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\fci\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 0    math
# 4     bio
# 5     bio
# Name: department, dtype: str
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\FCI\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# 5. Data-cleaning exercise: Load the provided messy CSV — fix inconsistent column names, strip
# whitespace from strings,

# %%
data=r'C:\Users\FCI\Desktop\assesments\messy_sales.csv'
df1=pd.read_csv(data)
print(df1)
# Out:
#      Customer Name    order_ID           E-Mail Address   Signup Date   \
# 0     Aisha Rahman        1001     AISHA.R@example.COM      2023-01-15
# 1        Ben Okafor       1002  ben.okafor@example.com      15/02/2023
# 2        ben okafor       1002   ben.okafor@example.com     15/02/2023
# 3         Chen  Wei       1003     chen.wei@example.com     2023-03-01
# 4               NaN       1004      d.mehta@example.com     2023-03-12
# 5        Diya Mehta       1004      D.MEHTA@EXAMPLE.COM     2023-03-12
# 6      Elena Novak        1005      elena.novak@example     2023-04-02
# 7        Farhan Ali       1006   farhan.ali@example.com  not available
# 8         Grace Lin       1007    grace.lin@example.com     2023-05-20
# 9      Hiro  Tanaka       1008  hiro.tanaka@example.com     2023-06-11
# 10         Ivy Chen       1009                      NaN     2023-07-04
# 11       Jonas Berg       1010   jonas.berg@example.com     2023-08-19
# 12     Kavya  Nair        1011   kavya.nair@example.com     2023-09-01
# 13     Liam O'Brien       1012  liam.obrien@example.com     2023-10-23
# 14       Mei  Zhang       1013   MEI.ZHANG@Example.com      2023-11-30
#
#    Order Total  Qty  Country     Status
# 0     1,250.00    3    india    shipped
# 1       899.50    2       IN    Shipped
# 2       899.50    2       IN    Shipped
# 3          NaN    1    China    PENDING
# 4        45.00    1    India    pending
# 5        45.00    1    India    pending
# 6         2300    4  czechia  cancelled
# 7       780.25  two    India    shipped
# 8       -99.00    1    china    SHIPPED
# 9      1500.75    5    Japan  delivered
# 10      320.10    2       JP  Delivered
# 11   12,000.00    1   Sweden        NaN
# 12      610.00    3    INDIA    shipped
# 13         NaN    0  Ireland  Cancelled
# 14      455.40    2       CN    pending

# %%
df1['customer_name']=df1['Customer Name'].strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Customer Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df1['customer_name']=df1['Customer Name'].strip()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Customer Name'
